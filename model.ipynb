# %%
from ultralytics import YOLO

# %%
model = YOLO('yolov8n.pt')

# %%
model.train(data = 'datasets/data.yaml', epochs = 10)
# Out:
# Ultralytics YOLOv8.1.18 🚀 Python-3.11.8 torch-2.2.1+cpu CPU (Intel Core(TM) i7-6700HQ 2.60GHz)
# ...

# %%
infer = YOLO('runs/detect/train4/weights/best.pt')

# %%
infer.predict('datasets/test/images/', save = True)
# Out:
# image 1/50 c:\Users\Waynes\Documents\code\fsl v2\datasets\test\images\bread_11taoceh_0-MOV0060_jpg.rf.207e8389afe61f30d98229254189ec0d.jpg: 640x640 1 bread, 215.0ms
# image 2/50 c:\Users\Waynes\Documents\code\fsl v2\datasets\test\images\bread_11taoceh_0-MOV0110_jpg.rf.70fe8c1e0aefd511bc60994dd32423f1.jpg: 640x640 1 bread, 186.0ms
# image 3/50 c:\Users\Waynes\Documents\code\fsl v2\datasets\test\images\bread_4wjsa5wq_0-MOV0040_jpg.rf.b949d78fdfff580a3316ed51ffbf787a.jpg: 640x640 (no detections), 200.0ms
# image 4/50 c:\Users\Waynes\Documents\code\fsl v2\datasets\test\images\bread_4wjsa5wq_0-MOV0100_jpg.rf.e7853232e6dbf7adb604841ba650fff2.jpg: 640x640 1 bread, 187.0ms
# image 5/50 c:\Users\Waynes\Documents\code\fsl v2\datasets\test\images\bread_940bqr4z_0-MOV0080_jpg.rf.e477a49f3c77d1291523b467a3f13ba7.jpg: 640x640 1 bread, 177.0ms
# ...

# %%
# !yolo detect predict model="runs/detect/train4/weights/best.pt" source="videos/bread_titl2dvs_0.MOV"
# Out:
# Ultralytics YOLOv8.1.18 🚀 Python-3.11.8 torch-2.2.1+cpu CPU (Intel Core(TM) i7-6700HQ 2.60GHz)
# Model summary (fused): 168 layers, 3006428 parameters, 0 gradients, 8.1 GFLOPs
#
# video 1/1 (1/244) c:\Users\Waynes\Documents\code\fsl v2\videos\bread_titl2dvs_0.MOV: 384x640 (no detections), 218.0ms
# video 1/1 (2/244) c:\Users\Waynes\Documents\code\fsl v2\videos\bread_titl2dvs_0.MOV: 384x640 (no detections), 186.0ms
# video 1/1 (3/244) c:\Users\Waynes\Documents\code\fsl v2\videos\bread_titl2dvs_0.MOV: 384x640 (no detections), 220.0ms
# video 1/1 (4/244) c:\Users\Waynes\Documents\code\fsl v2\videos\bread_titl2dvs_0.MOV: 384x640 (no detections), 225.0ms
# video 1/1 (5/244) c:\Users\Waynes\Documents\code\fsl v2\videos\bread_titl2dvs_0.MOV: 384x640 (no detections), 153.0ms
# video 1/1 (6/244) c:\Users\Waynes\Documents\code\fsl v2\videos\bread_titl2dvs_0.MOV: 384x640 (no detections), 146.0ms
# ...

# %%
import cv2

# %%
results = infer.predict(source="0", show=True)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 1/1: 0... Success ✅ (inf frames of shape 640x480 at 30.00 FPS)
#
#
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# 0: 480x640 (no detections), 283.0ms
# 0: 480x640 (no detections), 260.0ms
# 0: 480x640 (no detections), 221.0ms
# 0: 480x640 (no detections), 224.0ms
# 0: 480x640 (no detections), 174.0ms
# 0: 480x640 (no detections), 199.0ms
# 0: 480x640 (no detections), 200.0ms
# 0: 480x640 (no detections), 236.0ms
# 0: 480x640 (no detections), 204.0ms
# ...
